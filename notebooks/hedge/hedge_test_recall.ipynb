# %%
import sys
from pathlib import Path

PROJECT_ROOT = next(p for p in [Path.cwd(), *Path.cwd().parents] if (p / "models" / "hedge" / "hedge_detector.py").exists())
HEDGE_DIR = PROJECT_ROOT / "models" / "hedge"
if str(HEDGE_DIR) not in sys.path:
    sys.path.insert(0, str(HEDGE_DIR))

from hedge_detector import detect_hedge_expressions
